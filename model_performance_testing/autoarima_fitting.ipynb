# %% [markdown]
# ## Auto-fitting SARIMA Model For All Wards

# %% [markdown]
# ### 1. Load and Preprocess Burglary Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pmdarima.arima import auto_arima, ADFTest
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Load data and aggregate to ward-monthly counts
burglary = pd.read_csv('../data/residential_burglary.csv')

# Combine 'Year' and 'Month' into a single datetime column
burglary ["Month"] = pd.to_datetime(burglary ["Year"].astype(str) + "-" + burglary ["Month"].astype(str), format="%Y-%m")

burglary_monthly = burglary.groupby(["Ward Code", "Month"]).size().reset_index(name="Count")

# Extract the year from the 'Month' column for merging with the population data
burglary_monthly['Year'] = burglary_monthly['Month'].dt.year

print("Raw data overview:")
print(f"Total wards: {burglary_monthly['Ward Code'].nunique()}")
print(f"Time range: {burglary_monthly['Month'].min()} to {burglary_monthly['Month'].max()}")

burglary_monthly
# Out:
# Raw data overview:
# Total wards: 679
# Time range: 2013-12-01 00:00:00 to 2025-02-01 00:00:00
#        Ward Code      Month  Count  Year
# 0      E05009317 2013-12-01      8  2013
# 1      E05009317 2014-01-01     23  2014
# 2      E05009317 2014-02-01     12  2014
# 3      E05009317 2014-03-01     11  2014
# 4      E05009317 2014-04-01     21  2014
# ...          ...        ...    ...   ...
# 89633  E05014119 2024-10-01      1  2024
# 89634  E05014119 2024-11-01      2  2024
# 89635  E05014119 2024-12-01      4  2024
# 89636  E05014119 2025-01-01      3  2025
# 89637  E05014119 2025-02-01      4  2025
#
# [89638 rows x 4 columns]

# %% [markdown]
# ### 2. Define Oscillation Capture Score for Evaluating the Fitting of SARIMA Models

# %%
models_order_df = pd.read_csv('../data/density_models_orders.csv')
models_order_df.rename(columns={'Ward code': 'Ward Code'}, inplace=True)


def oscillation_capture_score(actual, predicted):
    """Calculate a composite score that detects oscillation pattern matching"""
    n = len(actual)
    if n < 3:
        return 0.0  # Not enough data

    # 1. Detrended Variability Ratio (DVR)
    var_actual = np.var(actual)
    var_pred = np.var(predicted)

    # Handle near-zero variance cases
    if var_actual < 1e-10 and var_pred < 1e-10:
        dvr = 1.0
    elif var_actual < 1e-10:
        dvr = 0.0
    else:
        dvr = min(var_pred / var_actual, 2.0)  # Cap at 2.0

    # 3. Smoothness Penalty (SP)
    pred_diff = np.diff(predicted)
    sp = 1 - np.exp(-np.mean(np.abs(pred_diff)) / max(1, np.mean(np.abs(np.diff(actual)))))

    # Combine components
    ocs = 0.3 * dvr + 0.7 * sp
    return ocs, dvr, sp

models_order_df
# Out:
#      Ward Code      Order Seasonal order
# 0    E05014058  (1, 0, 0)  (2, 1, 1, 12)
# 1    E05014071  (0, 0, 1)  (0, 1, 1, 12)
# 2    E05014059  (0, 0, 0)  (1, 1, 2, 12)
# 3    E05014069  (0, 0, 0)  (2, 1, 0, 12)
# 4    E05014063  (0, 0, 0)  (3, 1, 0, 12)
# ..         ...        ...            ...
# 673  E05013922  (1, 0, 1)  (3, 1, 0, 12)
# 674  E05013759  (1, 0, 1)  (2, 1, 1, 12)
# 675  E05009326  (0, 0, 0)  (2, 1, 1, 12)
# 676  E05013934  (0, 0, 0)  (0, 1, 1, 12)
# 677  E05013929  (1, 0, 0)  (2, 1, 1, 12)
#
# [678 rows x 3 columns]

# %% [markdown]
# ### 3. SARIMA Forecasting for All Wards

# %%
import warnings

warnings.filterwarnings("ignore")

def analyze_ward(ward_code, ward_df, test_months=26):
    """Analyze a single ward's SARIMA performance"""
    try:
        ward_df = ward_df[['Month', 'Count']].set_index('Month').asfreq('MS')

        if ward_df.isnull().values.any():
            print(f"{ward_code} has NaN values")
            if ward_df.isnull().sum().sum() > 10:
                print(f"{ward_code} has more than 10 NaN values, aborted")
                return None
            ward_df.fillna(0, inplace=True)

        # Filter wards with sufficient history
        if len(ward_df) < test_months * 2:
            print(f"{ward_code} has insufficient data")
            print(ward_df)
            return None

        # Split data
        train = ward_df.iloc[:-test_months]
        test = ward_df.iloc[-test_months:]

        # Use per-computed model orders from previous run to save time
        # model = SARIMAX(train["Count"],
        #         order=ast.literal_eval(model_order[["Order"]].values[0][0]),  # Use the correct normal order
        #        seasonal_order=ast.literal_eval(model_order[["Seasonal order"]].values[0][0]))

        # Auto-fit SARIMA
        fitted_model = auto_arima(train['Count'], start_p=0, d=0, start_q=0, max_p=3, max_d=3, max_q=3,
                                 start_P=0, D=1, start_Q=0, max_P=3, max_Q=3, m=12,
                                 seasonal=True, error_action='ignore', suppress_warnings=True, stepwise=True,
                                 random_state=2025, n_fits=10,
                                 stationary=ADFTest(alpha=0.05).should_diff(train['Count'])[1])

        model = SARIMAX(train['Count'],
                       order=fitted_model.order,  # Use the correct normal order
                       seasonal_order=(fitted_model.order[0], fitted_model.order[1], fitted_model.order[2], 12))

        results = model.fit(disp=False)

        # Generate predictions
        preds = results.get_forecast(steps=test_months).predicted_mean

        # Calculate residuals
        residuals = np.subtract(test['Count'].to_numpy(), preds)

        print(f"{ward_code} Completed")

        return {
            'ward_code': ward_code,
            'train_size': len(train),
            'test_size': len(test),
            'residuals': residuals,
            'predicted': preds,
            "fitting_score": oscillation_capture_score(test["Count"].values, preds.values),
            'actual': test['Count'].values,
            'model_order': str(model.order),
            'model_seasonal_order': str(model.seasonal_order)
        }
    except Exception as e:
        print(f"Error processing {ward_df['Ward Code'].iloc[0]}: {str(e)}")
        return None

# Process all wards
results = []
# i=0
for ward_code, group in burglary_monthly.groupby('Ward Code'):
    # if i > 10:
    #     break
    analysis = analyze_ward(ward_code, group)
    if analysis:
        results.append(analysis)
        # i += 1


# with mp.Pool(processes=mp.cpu_count()) as pool:
#     args = [(ward_code, group) for ward_code, group in burglary_monthly.groupby('Ward Code')]
#     results = pool.map(analyze_ward, args)

# Remove None results
results = [res for res in results if res is not None]

print(f"\nSuccessfully processed {len(results)} wards with sufficient data")

warnings.filterwarnings("default")
# Out:
# E05009317 Completed
# E05009318 Completed
# E05009319 Completed
# E05009320 Completed
# E05009321 has NaN values
# E05009321 Completed
# E05009322 Completed
# E05009323 Completed
# E05009324 has NaN values
# E05009324 Completed
# E05013797 Completed
# E05013798 Completed
# E05013799 Completed
# E05013800 Completed
# E05013801 Completed
# E05013802 Completed
# E05013803 has NaN values
# E05013803 Completed
# E05013804 Completed
# E05013805 Completed
# E05013806 Completed
# E05013807 has NaN values
# E05013807 Completed
# E05013808 Completed
# E05013809 has NaN values
# E05013809 Completed
# E05013810 has NaN values
# E05013810 Completed
# E05013811 has NaN values
# E05013811 Completed
# E05013812 has NaN values
# E05013812 Completed
# E05013813 has NaN values
# E05013813 Completed
# E05013814 has NaN values
# E05013814 Completed
# E05013815 has NaN values
# E05013815 Completed
# E05013816 has NaN values
# E05013816 Completed
# E05013817 has NaN values
# E05013817 Completed
# E05013818 has NaN values
# E05013818 Completed
# E05013819 has NaN values
# E05013819 has more than 10 NaN values, aborted
# E05013820 has NaN values
# E05013820 Completed
# E05013821 has NaN values
# E05013821 has more than 10 NaN values, aborted
# E05013822 has NaN values
# E05013822 Completed
# E05013823 has NaN values
# E05013823 Completed
# E05013824 has NaN values
# E05013824 Completed
# E05013825 has NaN values
# E05013825 Completed
# E05013826 has NaN values
# E05013826 has more than 10 NaN values, aborted
# E05013827 has NaN values
# E05013827 Completed
# E05013828 has NaN values
# E05013828 Completed
# E05013829 has NaN values
# E05013829 Completed
# E05013882 has NaN values
# E05013882 Completed
# E05013883 has NaN values
# E05013883 Completed
# E05013884 has NaN values
# E05013884 Completed
# E05013885 has NaN values
# E05013885 Completed
# E05013886 has NaN values
# E05013886 Completed
# E05013887 Completed
# E05013888 has NaN values
# E05013888 Completed
# E05013889 has NaN values
# E05013889 Completed
# E05013890 has NaN values
# E05013890 Completed
# E05013891 has NaN values
# E05013891 Completed
# E05013892 Completed
# E05013893 has NaN values
# E05013893 Completed
# E05013894 has NaN values
# E05013894 Completed
# E05013895 Completed
# E05013896 has NaN values
# E05013896 Completed
# E05013897 has NaN values
# E05013897 Completed
# E05013898 has NaN values
# E05013898 has more than 10 NaN values, aborted
# E05013899 has NaN values
# E05013899 Completed
# E05013900 has NaN values
# E05013900 Completed
# E05013901 has NaN values
# E05013901 Completed
# E05013902 Completed
# E05013903 has NaN values
# E05013903 Completed
# E05013904 Completed
# E05013905 Completed
# E05013906 has NaN values
# E05013906 Completed
# E05013907 has NaN values
# E05013907 Completed
# E05013908 Completed
# E05013909 Completed
# E05013910 Completed
# E05013911 has NaN values
# E05013911 Completed
# E05013912 Completed
# E05013913 has NaN values
# E05013913 Completed
# E05013914 has NaN values
# E05013914 Completed
# E05013915 has NaN values
# E05013915 Completed
# E05013916 Completed
# E05013917 has NaN values
# E05013917 Completed
# E05013918 has NaN values
# E05013918 Completed
# E05013919 has NaN values
# E05013919 Completed
# E05013920 Completed
# E05013921 has NaN values
# E05013921 has more than 10 NaN values, aborted
# E05013922 has NaN values
# E05013922 has more than 10 NaN values, aborted
# E05013923 has NaN values
# E05013923 Completed
# E05013924 Completed
# E05013925 has NaN values
# E05013925 has insufficient data
#             Count
# Month
# 2022-10-01    1.0
# 2022-11-01    0.0
# 2022-12-01    0.0
# 2023-01-01    0.0
# 2023-02-01    2.0
# 2023-03-01    0.0
# 2023-04-01    2.0
# 2023-05-01   10.0
# 2023-06-01    7.0
# 2023-07-01    9.0
# 2023-08-01   13.0
# 2023-09-01   16.0
# 2023-10-01   19.0
# 2023-11-01   31.0
# 2023-12-01   20.0
# 2024-01-01   11.0
# 2024-02-01   16.0
# 2024-03-01   12.0
# 2024-04-01    8.0
# 2024-05-01   11.0
# 2024-06-01    5.0
# 2024-07-01   14.0
# 2024-08-01   10.0
# 2024-09-01    9.0
# 2024-10-01   14.0
# 2024-11-01    9.0
# 2024-12-01   10.0
# 2025-01-01    6.0
# 2025-02-01    7.0
# E05013926 has NaN values
# E05013926 Completed
# E05013927 has NaN values
# E05013927 Completed
# E05013928 has NaN values
# E05013928 has more than 10 NaN values, aborted
# E05013929 has NaN values
# E05013929 has more than 10 NaN values, aborted
# E05013930 has NaN values
# E05013930 has more than 10 NaN values, aborted
# E05013931 has NaN values
# E05013931 has more than 10 NaN values, aborted
# E05013932 has NaN values
# E05013932 Completed
# E05013933 has NaN values
# E05013933 has more than 10 NaN values, aborted
# E05013934 has NaN values
# E05013934 has more than 10 NaN values, aborted
# E05013935 has NaN values
# E05013935 has more than 10 NaN values, aborted
# E05013936 has NaN values
# E05013936 has more than 10 NaN values, aborted
# E05013937 has NaN values
# E05013937 Completed
# E05013938 has NaN values
# E05013938 Completed
# E05013939 has NaN values
# E05013939 has more than 10 NaN values, aborted
# E05013940 has NaN values
# E05013940 Completed
# E05013941 Completed
# E05013942 has NaN values
# E05013942 has more than 10 NaN values, aborted
# E05013943 has NaN values
# E05013943 Completed
# E05013944 has NaN values
# E05013944 Completed
# E05013945 has NaN values
# E05013945 Completed
# E05013946 has NaN values
# E05013946 Completed
# E05013967 has NaN values
# E05013967 Completed
# E05013968 has NaN values
# E05013968 has more than 10 NaN values, aborted
# E05013969 Completed
# E05013970 has NaN values
# E05013970 Completed
# E05013971 Completed
# E05013972 has NaN values
# E05013972 has more than 10 NaN values, aborted
# E05013973 has NaN values
# E05013973 Completed
# E05013974 Completed
# E05013975 Completed
# E05013976 has NaN values
# E05013976 Completed
# E05013977 Completed
# E05013978 has NaN values
# E05013978 Completed
# E05013979 has NaN values
# E05013979 Completed
# E05013980 has NaN values
# E05013980 Completed
# E05013981 has NaN values
# E05013981 Completed
# E05013982 has NaN values
# E05013982 Completed
# E05013983 has NaN values
# E05013983 Completed
# E05013984 has NaN values
# E05013984 Completed
# E05013985 Completed
# E05013986 has NaN values
# E05013986 Completed
# E05013987 Completed
# E05013988 has NaN values
# E05013988 Completed
# E05013989 has NaN values
# E05013989 has more than 10 NaN values, aborted
# E05013990 Completed
# E05013991 Completed
# E05013992 has NaN values
# E05013992 Completed
# E05013993 Completed
# E05013994 has NaN values
# E05013994 Completed
# E05013995 Completed
# E05013996 has NaN values
# E05013996 has more than 10 NaN values, aborted
# E05014109 has NaN values
# E05014109 Completed
# E05014110 has NaN values
# E05014110 Completed
# E05014111 Completed
# E05014112 Completed
# E05014113 has NaN values
# E05014113 Completed
# E05014114 Completed
# E05014115 Completed
# E05014116 has NaN values
# E05014116 Completed
# E05014117 has NaN values
# E05014117 Completed
# E05014118 Completed
# E05014119 has NaN values
# E05014119 Completed
#
# Successfully processed 631 wards with sufficient data

# %% [markdown]
# ### 4. Performance Analysis

# %%
# Combine all residuals
all_mae, all_rmse, all_fitting_score = [], [], []
positive_count = 0
total_residuals = 0

for result in results:
    residuals = result['residuals']
    all_mae.append(mean_absolute_error(result["actual"], result["predicted"]))
    all_rmse.append(np.sqrt(mean_squared_error(result["actual"], result["predicted"])))
    all_fitting_score.append(result["fitting_score"])

# Calculate statistics
avg_mae = np.mean(all_mae)
avg_rmse = np.mean(all_rmse)
ocs_list, dvr_list, sp_list = [], [], []

for score in all_fitting_score:
    ocs, dvr, sp = score
    ocs_list.append(ocs)
    dvr_list.append(dvr)
    sp_list.append(sp)
avg_fitting_score = (np.mean(ocs_list), np.mean(dvr_list), np.mean(sp_list))

print(f"\nAverage MAE: {avg_mae:.2f}")
print(f"Average RMSE: {avg_rmse:.2f}")
# print(f"Average fitting score: {avg_fitting_score:.2f}")
print(avg_fitting_score)
# Out:
# Average MAE: 4.13
# Average RMSE: 4.91
# (0.12426498314972576, 0.1397765064316779, 0.11761718745746058)

# %% [markdown]
# ### 5. Visualisation

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

def plot_sarima_validation(result):
    """Plot training data, actual test values and predictions for a single ward"""
    plt.figure(figsize=(14, 7))

    # Extract data
    ward_code = result['ward_code']
    train_dates = burglary_monthly[burglary_monthly['Ward Code'] == ward_code]['Month'].iloc[:-26]
    train_counts = burglary_monthly[burglary_monthly['Ward Code'] == ward_code]['Count'].iloc[:-26]
    test_dates = burglary_monthly[burglary_monthly['Ward Code'] == ward_code]['Month'].iloc[-26:]

    # Create plots
    plt.plot(train_dates, train_counts, 'b-', label='Training Data')
    plt.plot(test_dates, result['actual'], 'ko-', label='Actual Test Values')
    plt.plot(test_dates, result['predicted'], 'r--', label='SARIMA Predictions')

    # Formatting
    plt.title(f'''SARIMA Validation for Ward {ward_code}
    Order: {result['model_order']}, Seasonal Order: {result['model_seasonal_order']}''')
    plt.xlabel('Date')
    plt.ylabel('Burglary Count')
    plt.legend()
    plt.grid(True)

    # Add metrics
    rmse = np.sqrt(mean_squared_error(result['actual'], result['predicted']))
    mae = mean_absolute_error(result['actual'], result['predicted'])
    plt.text(0.05, 0.95,
            f'Test RMSE: {rmse:.2f}\nTest MAE: {mae:.2f}',
            transform=plt.gca().transAxes,
            verticalalignment='top',
            bbox=dict(facecolor='white', alpha=0.8))

    plt.show()

# Plot first 3 wards as examples
for i, result in enumerate(results[:200]):
    plot_sarima_validation(result)
    print(f"\n{'-'*50}\nResidual Statistics for Ward {result['ward_code']}:")
    # print(f"Fitting Score: {result['fitting_score']:.2f}")
    print(result["fitting_score"])
